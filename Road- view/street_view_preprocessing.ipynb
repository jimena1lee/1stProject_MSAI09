# %% [markdown]
# # 거리뷰 이미지를 이용한 불법 주정차 분석

# %% [markdown]
# ## 1) 거리뷰 이미지 수집

# %% [markdown]
# ### 1. 구글 street view API 사용
# - 거리뷰 이미지를 url로 바로 받아올 수 있음
# - 단점: 상세한 거리뷰 이미지가 없음

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
import time

load_dotenv()  
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
GOOGLE_API_KEY = "발급받은 API 키"

def check_streetview_available(lat, lng):
    """
    왜 메타데이터 API를 먼저 쓰냐:
    이미지 API는 없는 곳에 요청해도 과금될 수 있지만
    메타데이터 API는 무료이고 이미지 존재 여부를 먼저 확인할 수 있음
    """
    url = (
        f"https://maps.googleapis.com/maps/api/streetview/metadata"
        f"?location={lat},{lng}"
        f"&key={GOOGLE_API_KEY}"
    )
    res = requests.get(url)
    data = res.json()

    # status가 OK면 이미지 있음, ZERO_RESULTS면 없음
    return data.get("status") == "OK"

def fetch_streetview(lat, lng, zone_id, save_dir="streetview_images"):
    os.makedirs(save_dir, exist_ok=True)
    headings = [0, 90, 180, 270]
    saved_paths = []

    for heading in headings:
        url = (
            f"https://maps.googleapis.com/maps/api/streetview"
            f"?size=640x480"
            f"&location={lat},{lng}"
            f"&heading={heading}"
            f"&fov=90"
            f"&key={GOOGLE_API_KEY}"
        )
        res = requests.get(url)
        if res.status_code == 200:
            path = f"{save_dir}/{zone_id}_h{heading}.jpg"
            with open(path, 'wb') as f:
                f.write(res.content)
            saved_paths.append(path)
        time.sleep(0.2)

    return saved_paths

# 실행
safezone_df = pd.read_csv('./어린이보호구역_위치정보.csv')

available = []
unavailable = []

for idx, row in safezone_df.iterrows():
    lat, lng = row['위도'], row['경도']

    if check_streetview_available(lat, lng):
        paths = fetch_streetview(lat, lng, zone_id=idx)
        available.append(row['대상시설명'])
        print(f"✅ [{idx}] {row['대상시설명']} → {len(paths)}장 수집")
    else:
        unavailable.append(row['대상시설명'])
        print(f"❌ [{idx}] {row['대상시설명']} → 이미지 없음 스킵")

print(f"\n수집 성공: {len(available)}개 / 스킵: {len(unavailable)}개")
print(f"\n이미지 없는 구역: {unavailable}")
# Out:
# ❌ [0] 배성유치원 → 이미지 없음 스킵
# ❌ [1] 이솔유치원 → 이미지 없음 스킵
# ❌ [2] 성모 유치원 → 이미지 없음 스킵
# ❌ [3] 판교샘유치원 → 이미지 없음 스킵
# ❌ [4] 건영장안유치원 → 이미지 없음 스킵
# ❌ [5] 뽀뽀뽀유치원 → 이미지 없음 스킵
# ❌ [6] 해나유치원 → 이미지 없음 스킵
# ❌ [7] 샛별유치원 → 이미지 없음 스킵
# ❌ [8] 성마르코유치원 → 이미지 없음 스킵
# ❌ [9] 숲리라유치원 → 이미지 없음 스킵
# ❌ [10] 즐거운유치원 → 이미지 없음 스킵
# ❌ [11] 혜성유치원 → 이미지 없음 스킵
# ❌ [12] 산성어린이집 → 이미지 없음 스킵
# ❌ [13] 성남어린이집 → 이미지 없음 스킵
# ❌ [14] 성현어린이집 → 이미지 없음 스킵
# ❌ [15] 리플플러스어린이집 → 이미지 없음 스킵
# ❌ [16] 당촌초등학교 → 이미지 없음 스킵
# ❌ [17] 수내초등학교 → 이미지 없음 스킵
# ❌ [18] 산성3어린이집 → 이미지 없음 스킵
# ❌ [19] 은서유치원 → 이미지 없음 스킵
# ❌ [20] 예원유치원 → 이미지 없음 스킵
# ❌ [21] 다솜유치원 → 이미지 없음 스킵
# ❌ [22] 아름다운유치원 → 이미지 없음 스킵
# ❌ [23] 세화유치원 → 이미지 없음 스킵
# ❌ [24] 분당중앙유치원 → 이미지 없음 스킵
# ❌ [25] 보듬이나눔이어린이집 → 이미지 없음 스킵
# ❌ [26] 운중하나어린이집 → 이미지 없음 스킵
# ❌ [27] 푸르니이매어린이집 → 이미지 없음 스킵
# ❌ [28] 성남혜은학교 → 이미지 없음 스킵
# ❌ [29] 성은특수학교 → 이미지 없음 스킵
# ❌ [30] 케이디엘피어학원 → 이미지 없음 스킵
# ❌ [31] 판교초등학교 → 이미지 없음 스킵
# ❌ [32] 성남동초등학교 → 이미지 없음 스킵
# ❌ [33] 태평초등학교 → 이미지 없음 스킵
# ❌ [34] 성수초등학교 → 이미지 없음 스킵
# ❌ [35] 금빛초등학교 → 이미지 없음 스킵
# ❌ [36] 왕남초등학교 → 이미지 없음 스킵
# ❌ [37] 검단초등학교 → 이미지 없음 스킵
# ❌ [38] 불곡초등학교 → 이미지 없음 스킵
# ❌ [39] 성남매송초등학교 → 이미지 없음 스킵
# ❌ [40] 성남정자초등학교 → 이미지 없음 스킵
# ❌ [41] 중탑초등학교 → 이미지 없음 스킵
# ❌ [42] 초림초등학교 → 이미지 없음 스킵
# ❌ [43] 미래유치원 → 이미지 없음 스킵
# ❌ [44] 성체유치원 → 이미지 없음 스킵
# ❌ [45] 은솔유치원 → 이미지 없음 스킵
# ❌ [46] 한양어린이집 → 이미지 없음 스킵
# ❌ [47] 신흥제3어린이집 → 이미지 없음 스킵
# ❌ [48] 복정2어린이집 → 이미지 없음 스킵
# ❌ [49] 아이세상 어린이집 → 이미지 없음 스킵
# ❌ [50] 중앙동어린이집 → 이미지 없음 스킵
# ❌ [51] 금광2동제2어린이집 → 이미지 없음 스킵
# ❌ [52] 서광어린이집 → 이미지 없음 스킵
# ❌ [53] 분당어린이집 → 이미지 없음 스킵
# ❌ [54] 서현어린이집 → 이미지 없음 스킵
# ❌ [55] 갈보리어린이집 → 이미지 없음 스킵
# ❌ [56] 휴맥스어린이집 → 이미지 없음 스킵
# ❌ [57] 삼평어린이집 → 이미지 없음 스킵
# ❌ [58] 판교제2어린이집 → 이미지 없음 스킵
# ❌ [59] 구미동어린이집 → 이미지 없음 스킵
# ❌ [60] 예림어린이집 → 이미지 없음 스킵
# ❌ [61] 하탑초등학교 → 이미지 없음 스킵
# ❌ [62] 늘푸른초등학교 → 이미지 없음 스킵
# ❌ [63] 산운초등학교 → 이미지 없음 스킵
# ❌ [64] 운중초등학교 → 이미지 없음 스킵
# ❌ [65] 신백현초등학교 → 이미지 없음 스킵
# ❌ [66] 성남화랑초등학교 → 이미지 없음 스킵
# ❌ [67] 고등나래 유치원 → 이미지 없음 스킵
# ❌ [68] 성남중앙초등학교 → 이미지 없음 스킵
# ❌ [69] 대원초등학교 → 이미지 없음 스킵
# ❌ [70] 대일초등학교 → 이미지 없음 스킵
# ❌ [71] 성남제일초등학교 → 이미지 없음 스킵
# ❌ [72] 성남북초등학교 → 이미지 없음 스킵
# ❌ [73] 성남수정초등학교 → 이미지 없음 스킵
# ❌ [74] 수진초등학교 → 이미지 없음 스킵
# ❌ [75] 희망대초등학교 → 이미지 없음 스킵
# ❌ [76] 성남서초등학교 → 이미지 없음 스킵
# ❌ [77] 성남신흥초등학교 → 이미지 없음 스킵
# ❌ [78] 단대초등학교 → 이미지 없음 스킵
# ❌ [79] 성남양지초등학교 → 이미지 없음 스킵
# ❌ [80] 위례한빛초등학교 → 이미지 없음 스킵
# ❌ [81] 위례푸른초등학교 → 이미지 없음 스킵
# ❌ [82] 금상초등학교 → 이미지 없음 스킵
# ❌ [83] 상원초등학교 → 이미지 없음 스킵
# ❌ [84] 상탑초등학교 → 이미지 없음 스킵
# ❌ [85] 서현초등학교 → 이미지 없음 스킵
# ❌ [86] 성남장안초등학교 → 이미지 없음 스킵
# ❌ [87] 안말초등학교 → 이미지 없음 스킵
# ❌ [88] 야탑초등학교 → 이미지 없음 스킵
# ❌ [89] 오리초등학교 → 이미지 없음 스킵
# ❌ [90] 이매초등학교 → 이미지 없음 스킵
# ❌ [91] 청솔초등학교 → 이미지 없음 스킵
# ❌ [92] 중원초등학교 → 이미지 없음 스킵
# ❌ [93] 중부초등학교 → 이미지 없음 스킵
# ❌ [94] 도촌초등학교 → 이미지 없음 스킵
# ❌ [95] 구미초등학교 → 이미지 없음 스킵
# ❌ [96] 돌마초등학교 → 이미지 없음 스킵
# ❌ [97] 미금초등학교 → 이미지 없음 스킵
# ❌ [98] 분당초등학교 → 이미지 없음 스킵
# ❌ [99] 성남여수초등학교 → 이미지 없음 스킵
# ❌ [100] 보평초등학교 → 이미지 없음 스킵
# ❌ [101] 낙생초등학교 → 이미지 없음 스킵
# ❌ [102] 성남은행초등학교 → 이미지 없음 스킵
# ❌ [103] 창조유치원 → 이미지 없음 스킵
# ❌ [104] 꾸러기유치원 → 이미지 없음 스킵
# ❌ [105] 은혜유치원 → 이미지 없음 스킵
# ❌ [106] 희영유치원 → 이미지 없음 스킵
# ❌ [107] 단대어린이집 → 이미지 없음 스킵
# ❌ [108] 신흥제2어린이집 → 이미지 없음 스킵
# ❌ [109] 한솔초등학교 → 이미지 없음 스킵
# ❌ [110] 성남송현초등학교 → 이미지 없음 스킵
# ❌ [111] 위례하늘유치원 → 이미지 없음 스킵
# ❌ [112] 단남초등학교 → 이미지 없음 스킵
# ❌ [113] 대하초등학교 → 이미지 없음 스킵
# ❌ [114] 복정초등학교 → 이미지 없음 스킵
# ❌ [115] 위례고운초등학교 → 이미지 없음 스킵
# ❌ [116] 위례중앙초등학교 → 이미지 없음 스킵
# ❌ [117] 불정초등학교 → 이미지 없음 스킵
# ❌ [118] 성남신기초등학교 → 이미지 없음 스킵
# ❌ [119] 하원초등학교 → 이미지 없음 스킵
# ❌ [120] 상대원초등학교 → 이미지 없음 스킵
# ❌ [121] 내정초등학교 → 이미지 없음 스킵
# ❌ [122] 백현초등학교 → 이미지 없음 스킵
# ❌ [123] 탄천초등학교 → 이미지 없음 스킵
# ❌ [124] 위례새초롱유치원 → 이미지 없음 스킵
# ❌ [125] 선경유치원 → 이미지 없음 스킵
# ❌ [126] 도촌유치원 → 이미지 없음 스킵
# ❌ [127] 안촌 유치원 → 이미지 없음 스킵
# ❌ [128] 꿈터 유치원 → 이미지 없음 스킵
# ❌ [129] 서울국제학교 → 이미지 없음 스킵
# ❌ [130] 성남초등학교 → 이미지 없음 스킵
# ❌ [131] 서당초등학교 → 이미지 없음 스킵
# ❌ [132] 양영초등학교 → 이미지 없음 스킵
# ❌ [133] 판교대장초등학교 → 이미지 없음 스킵
# ❌ [134] 신흥성모유치원 → 이미지 없음 스킵
# ❌ [135] 복정어린이집 → 이미지 없음 스킵
# ❌ [136] 다솜어린이집 → 이미지 없음 스킵
# ❌ [137] 하대원어린이집 → 이미지 없음 스킵
# ❌ [138] 판교어린이집 → 이미지 없음 스킵
# ❌ [139] 성남생명숲어린이집 → 이미지 없음 스킵
# ❌ [140] 늘사랑어린이집 → 이미지 없음 스킵
# ❌ [141] 수내동어린이집 → 이미지 없음 스킵
#
# 수집 성공: 0개 / 스킵: 142개
#
# 이미지 없는 구역: ['배성유치원', '이솔유치원', '성모 유치원', '판교샘유치원', '건영장안유치원', '뽀뽀뽀유치원', '해나유치원', '샛별유치원', '성마르코유치원', '숲리라유치원', '즐거운유치원', '혜성유치원', '산성어린이집', '성남어린이집', '성현어린이집', '리플플러스어린이집', '당촌초등학교', '수내초등학교', '산성3어린이집', '은서유치원', '예원유치원', '다솜유치원', '아름다운유치원', '세화유치원', '분당중앙유치원', '보듬이나눔이어린이집', '운중하나어린이집', '푸르니이매어린이집', '성남혜은학교', '성은특수학교', '케이디엘피어학원', '판교초등학교', '성남동초등학교', '태평초등학교', '성수초등학교', '금빛초등학교', '왕남초등학교', '검단초등학교', '불곡초등학교', '성남매송초등학교', '성남정자초등학교', '중탑초등학교', '초림초등학교', '미래유치원', '성체유치원', '은솔유치원', '한양어린이집', '신흥제3어린이집', '복정2어린이집', '아이세상 어린이집', '중앙동어린이집', '금광2동제2어린이집', '서광어린이집', '분당어린이집', '서현어린이집', '갈보리어린이집', '휴맥스어린이집', '삼평어린이집', '판교제2어린이집', '구미동어린이집', '예림어린이집', '하탑초등학교', '늘푸른초등학교', '산운초등학교', '운중초등학교', '신백현초등학교', '성남화랑초등학교', '고등나래 유치원', '성남중앙초등학교', '대원초등학교', '대일초등학교', '성남제일초등학교', '성남북초등학교', '성남수정초등학교', '수진초등학교', '희망대초등학교', '성남서초등학교', '성남신흥초등학교', '단대초등학교', '성남양지초등학교', '위례한빛초등학교', '위례푸른초등학교', '금상초등학교', '상원초등학교', '상탑초등학교', '서현초등학교', '성남장안초등학교', '안말초등학교', '야탑초등학교', '오리초등학교', '이매초등학교', '청솔초등학교', '중원초등학교', '중부초등학교', '도촌초등학교', '구미초등학교', '돌마초등학교', '미금초등학교', '분당초등학교', '성남여수초등학교', '보평초등학교', '낙생초등학교', '성남은행초등학교', '창조유치원', '꾸러기유치원', '은혜유치원', '희영유치원', '단대어린이집', '신흥제2어린이집', '한솔초등학교', '성남송현초등학교', '위례하늘유치원', '단남초등학교', '대하초등학교', '복정초등학교', '위례고운초등학교', '위례중앙초등학교', '불정초등학교', '성남신기초등학교', '하원초등학교', '상대원초등학교', '내정초등학교', '백현초등학교', '탄천초등학교', '위례새초롱유치원', '선경유치원', '도촌유치원', '안촌 유치원', '꿈터 유치원', '서울국제학교', '성남초등학교', '서당초등학교', '양영초등학교', '판교대장초등학교', '신흥성모유치원', '복정어린이집', '다솜어린이집', '하대원어린이집', '판교어린이집', '성남생명숲어린이집', '늘사랑어린이집', '수내동어린이집']

# %% [markdown]
# ### 2. 카카오맵 API + Selenium을 통해 직접 수집

# %%
# %pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from webdriver-manager) (1.2.1)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python311\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (2026.1.4)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import os
import pandas as pd

SAVE_DIR = "./roadview_images"
os.makedirs(SAVE_DIR, exist_ok=True)

def get_kakao_roadview(lat, lng, facility_name):
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    options.add_argument("--window-size=1280,720")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")

    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=options
    )

    try:
        url = f"https://map.kakao.com/link/roadview/{lat},{lng}"
        driver.get(url)
        time.sleep(4)

        if "준비 중" in driver.page_source:
            print(f"  ❌ [{facility_name}] 로드뷰 없음")
            return None

        # 파일명에 시설명 사용
        # 왜 replace('/', '_')냐: 시설명에 '/'가 있으면 경로로 인식돼서 오류 발생하기 때문
        safe_name = facility_name.replace('/', '_').replace(' ', '_')
        path = f"{SAVE_DIR}/{safe_name}_북쪽.png"
        driver.save_screenshot(path)
        print(f"  ✅ [{facility_name}] 저장 완료 → {path}")
        return path

    except Exception as e:
        print(f"  ❌ [{facility_name}] 오류: {e}")
        return None

    finally:
        driver.quit()


safezone_df = pd.read_csv('../../Preprocessing/외부안전위험요소/어린이보호구역_위치정보.csv')

for idx, row in safezone_df.iterrows():
    print(f"[{idx}] {row['대상시설명']} 수집 중...")
    get_kakao_roadview(row['위도'], row['경도'], facility_name=row['대상시설명'])
# Out:
# [0] 배성유치원 수집 중...
#   ✅ [배성유치원] 저장 완료 → ./roadview_images/배성유치원_북쪽.png
# [1] 이솔유치원 수집 중...
#   ✅ [이솔유치원] 저장 완료 → ./roadview_images/이솔유치원_북쪽.png
# [2] 성모 유치원 수집 중...
#   ✅ [성모 유치원] 저장 완료 → ./roadview_images/성모_유치원_북쪽.png
# [3] 판교샘유치원 수집 중...
#   ✅ [판교샘유치원] 저장 완료 → ./roadview_images/판교샘유치원_북쪽.png
# [4] 건영장안유치원 수집 중...
#   ✅ [건영장안유치원] 저장 완료 → ./roadview_images/건영장안유치원_북쪽.png
# [5] 뽀뽀뽀유치원 수집 중...
#   ✅ [뽀뽀뽀유치원] 저장 완료 → ./roadview_images/뽀뽀뽀유치원_북쪽.png
# [6] 해나유치원 수집 중...
#   ✅ [해나유치원] 저장 완료 → ./roadview_images/해나유치원_북쪽.png
# [7] 샛별유치원 수집 중...
#   ✅ [샛별유치원] 저장 완료 → ./roadview_images/샛별유치원_북쪽.png
# [8] 성마르코유치원 수집 중...
#   ✅ [성마르코유치원] 저장 완료 → ./roadview_images/성마르코유치원_북쪽.png
# [9] 숲리라유치원 수집 중...
#   ✅ [숲리라유치원] 저장 완료 → ./roadview_images/숲리라유치원_북쪽.png
# [10] 즐거운유치원 수집 중...
#   ✅ [즐거운유치원] 저장 완료 → ./roadview_images/즐거운유치원_북쪽.png
# [11] 혜성유치원 수집 중...
#   ✅ [혜성유치원] 저장 완료 → ./roadview_images/혜성유치원_북쪽.png
# [12] 산성어린이집 수집 중...
#   ✅ [산성어린이집] 저장 완료 → ./roadview_images/산성어린이집_북쪽.png
# [13] 성남어린이집 수집 중...
#   ✅ [성남어린이집] 저장 완료 → ./roadview_images/성남어린이집_북쪽.png
# [14] 성현어린이집 수집 중...
#   ✅ [성현어린이집] 저장 완료 → ./roadview_images/성현어린이집_북쪽.png
# [15] 리플플러스어린이집 수집 중...
#   ✅ [리플플러스어린이집] 저장 완료 → ./roadview_images/리플플러스어린이집_북쪽.png
# [16] 당촌초등학교 수집 중...
#   ✅ [당촌초등학교] 저장 완료 → ./roadview_images/당촌초등학교_북쪽.png
# [17] 수내초등학교 수집 중...
#   ✅ [수내초등학교] 저장 완료 → ./roadview_images/수내초등학교_북쪽.png
# [18] 산성3어린이집 수집 중...
#   ✅ [산성3어린이집] 저장 완료 → ./roadview_images/산성3어린이집_북쪽.png
# [19] 은서유치원 수집 중...
#   ✅ [은서유치원] 저장 완료 → ./roadview_images/은서유치원_북쪽.png
# [20] 예원유치원 수집 중...
#   ✅ [예원유치원] 저장 완료 → ./roadview_images/예원유치원_북쪽.png
# [21] 다솜유치원 수집 중...
#   ✅ [다솜유치원] 저장 완료 → ./roadview_images/다솜유치원_북쪽.png
# [22] 아름다운유치원 수집 중...
#   ✅ [아름다운유치원] 저장 완료 → ./roadview_images/아름다운유치원_북쪽.png
# [23] 세화유치원 수집 중...
#   ✅ [세화유치원] 저장 완료 → ./roadview_images/세화유치원_북쪽.png
# [24] 분당중앙유치원 수집 중...
#   ✅ [분당중앙유치원] 저장 완료 → ./roadview_images/분당중앙유치원_북쪽.png
# [25] 보듬이나눔이어린이집 수집 중...
#   ✅ [보듬이나눔이어린이집] 저장 완료 → ./roadview_images/보듬이나눔이어린이집_북쪽.png
# [26] 운중하나어린이집 수집 중...
#   ✅ [운중하나어린이집] 저장 완료 → ./roadview_images/운중하나어린이집_북쪽.png
# [27] 푸르니이매어린이집 수집 중...
#   ✅ [푸르니이매어린이집] 저장 완료 → ./roadview_images/푸르니이매어린이집_북쪽.png
# [28] 성남혜은학교 수집 중...
#   ✅ [성남혜은학교] 저장 완료 → ./roadview_images/성남혜은학교_북쪽.png
# [29] 성은특수학교 수집 중...
#   ✅ [성은특수학교] 저장 완료 → ./roadview_images/성은특수학교_북쪽.png
# [30] 케이디엘피어학원 수집 중...
#   ✅ [케이디엘피어학원] 저장 완료 → ./roadview_images/케이디엘피어학원_북쪽.png
# [31] 판교초등학교 수집 중...
#   ✅ [판교초등학교] 저장 완료 → ./roadview_images/판교초등학교_북쪽.png
# [32] 성남동초등학교 수집 중...
#   ✅ [성남동초등학교] 저장 완료 → ./roadview_images/성남동초등학교_북쪽.png
# [33] 태평초등학교 수집 중...
#   ✅ [태평초등학교] 저장 완료 → ./roadview_images/태평초등학교_북쪽.png
# [34] 성수초등학교 수집 중...
#   ✅ [성수초등학교] 저장 완료 → ./roadview_images/성수초등학교_북쪽.png
# [35] 금빛초등학교 수집 중...
#   ✅ [금빛초등학교] 저장 완료 → ./roadview_images/금빛초등학교_북쪽.png
# [36] 왕남초등학교 수집 중...
#   ✅ [왕남초등학교] 저장 완료 → ./roadview_images/왕남초등학교_북쪽.png
# [37] 검단초등학교 수집 중...
#   ✅ [검단초등학교] 저장 완료 → ./roadview_images/검단초등학교_북쪽.png
# [38] 불곡초등학교 수집 중...
#   ✅ [불곡초등학교] 저장 완료 → ./roadview_images/불곡초등학교_북쪽.png
# [39] 성남매송초등학교 수집 중...
#   ✅ [성남매송초등학교] 저장 완료 → ./roadview_images/성남매송초등학교_북쪽.png
# [40] 성남정자초등학교 수집 중...
#   ✅ [성남정자초등학교] 저장 완료 → ./roadview_images/성남정자초등학교_북쪽.png
# [41] 중탑초등학교 수집 중...
#   ✅ [중탑초등학교] 저장 완료 → ./roadview_images/중탑초등학교_북쪽.png
# [42] 초림초등학교 수집 중...
#   ✅ [초림초등학교] 저장 완료 → ./roadview_images/초림초등학교_북쪽.png
# [43] 미래유치원 수집 중...
#   ✅ [미래유치원] 저장 완료 → ./roadview_images/미래유치원_북쪽.png
# [44] 성체유치원 수집 중...
#   ✅ [성체유치원] 저장 완료 → ./roadview_images/성체유치원_북쪽.png
# [45] 은솔유치원 수집 중...
#   ✅ [은솔유치원] 저장 완료 → ./roadview_images/은솔유치원_북쪽.png
# [46] 한양어린이집 수집 중...
#   ✅ [한양어린이집] 저장 완료 → ./roadview_images/한양어린이집_북쪽.png
# [47] 신흥제3어린이집 수집 중...
#   ✅ [신흥제3어린이집] 저장 완료 → ./roadview_images/신흥제3어린이집_북쪽.png
# [48] 복정2어린이집 수집 중...
#   ✅ [복정2어린이집] 저장 완료 → ./roadview_images/복정2어린이집_북쪽.png
# [49] 아이세상 어린이집 수집 중...
#   ✅ [아이세상 어린이집] 저장 완료 → ./roadview_images/아이세상_어린이집_북쪽.png
# [50] 중앙동어린이집 수집 중...
#   ✅ [중앙동어린이집] 저장 완료 → ./roadview_images/중앙동어린이집_북쪽.png
# [51] 금광2동제2어린이집 수집 중...
#   ✅ [금광2동제2어린이집] 저장 완료 → ./roadview_images/금광2동제2어린이집_북쪽.png
# [52] 서광어린이집 수집 중...
#   ✅ [서광어린이집] 저장 완료 → ./roadview_images/서광어린이집_북쪽.png
# [53] 분당어린이집 수집 중...
#   ✅ [분당어린이집] 저장 완료 → ./roadview_images/분당어린이집_북쪽.png
# [54] 서현어린이집 수집 중...
#   ✅ [서현어린이집] 저장 완료 → ./roadview_images/서현어린이집_북쪽.png
# [55] 갈보리어린이집 수집 중...
#   ✅ [갈보리어린이집] 저장 완료 → ./roadview_images/갈보리어린이집_북쪽.png
# [56] 휴맥스어린이집 수집 중...
#   ✅ [휴맥스어린이집] 저장 완료 → ./roadview_images/휴맥스어린이집_북쪽.png
# [57] 삼평어린이집 수집 중...
#   ✅ [삼평어린이집] 저장 완료 → ./roadview_images/삼평어린이집_북쪽.png
# [58] 판교제2어린이집 수집 중...
#   ✅ [판교제2어린이집] 저장 완료 → ./roadview_images/판교제2어린이집_북쪽.png
# [59] 구미동어린이집 수집 중...
#   ✅ [구미동어린이집] 저장 완료 → ./roadview_images/구미동어린이집_북쪽.png
# [60] 예림어린이집 수집 중...
#   ✅ [예림어린이집] 저장 완료 → ./roadview_images/예림어린이집_북쪽.png
# [61] 하탑초등학교 수집 중...
#   ✅ [하탑초등학교] 저장 완료 → ./roadview_images/하탑초등학교_북쪽.png
# [62] 늘푸른초등학교 수집 중...
#   ✅ [늘푸른초등학교] 저장 완료 → ./roadview_images/늘푸른초등학교_북쪽.png
# [63] 산운초등학교 수집 중...
#   ✅ [산운초등학교] 저장 완료 → ./roadview_images/산운초등학교_북쪽.png
# [64] 운중초등학교 수집 중...
#   ✅ [운중초등학교] 저장 완료 → ./roadview_images/운중초등학교_북쪽.png
# [65] 신백현초등학교 수집 중...
#   ✅ [신백현초등학교] 저장 완료 → ./roadview_images/신백현초등학교_북쪽.png
# [66] 성남화랑초등학교 수집 중...
#   ✅ [성남화랑초등학교] 저장 완료 → ./roadview_images/성남화랑초등학교_북쪽.png
# [67] 고등나래 유치원 수집 중...
#   ✅ [고등나래 유치원] 저장 완료 → ./roadview_images/고등나래_유치원_북쪽.png
# [68] 성남중앙초등학교 수집 중...
#   ✅ [성남중앙초등학교] 저장 완료 → ./roadview_images/성남중앙초등학교_북쪽.png
# [69] 대원초등학교 수집 중...
#   ✅ [대원초등학교] 저장 완료 → ./roadview_images/대원초등학교_북쪽.png
# [70] 대일초등학교 수집 중...
#   ✅ [대일초등학교] 저장 완료 → ./roadview_images/대일초등학교_북쪽.png
# [71] 성남제일초등학교 수집 중...
#   ✅ [성남제일초등학교] 저장 완료 → ./roadview_images/성남제일초등학교_북쪽.png
# [72] 성남북초등학교 수집 중...
#   ✅ [성남북초등학교] 저장 완료 → ./roadview_images/성남북초등학교_북쪽.png
# [73] 성남수정초등학교 수집 중...
#   ✅ [성남수정초등학교] 저장 완료 → ./roadview_images/성남수정초등학교_북쪽.png
# [74] 수진초등학교 수집 중...
#   ✅ [수진초등학교] 저장 완료 → ./roadview_images/수진초등학교_북쪽.png
# [75] 희망대초등학교 수집 중...
#   ✅ [희망대초등학교] 저장 완료 → ./roadview_images/희망대초등학교_북쪽.png
# [76] 성남서초등학교 수집 중...
#   ✅ [성남서초등학교] 저장 완료 → ./roadview_images/성남서초등학교_북쪽.png
# [77] 성남신흥초등학교 수집 중...
#   ✅ [성남신흥초등학교] 저장 완료 → ./roadview_images/성남신흥초등학교_북쪽.png
# [78] 단대초등학교 수집 중...
#   ✅ [단대초등학교] 저장 완료 → ./roadview_images/단대초등학교_북쪽.png
# [79] 성남양지초등학교 수집 중...
#   ✅ [성남양지초등학교] 저장 완료 → ./roadview_images/성남양지초등학교_북쪽.png
# [80] 위례한빛초등학교 수집 중...
#   ✅ [위례한빛초등학교] 저장 완료 → ./roadview_images/위례한빛초등학교_북쪽.png
# [81] 위례푸른초등학교 수집 중...
#   ✅ [위례푸른초등학교] 저장 완료 → ./roadview_images/위례푸른초등학교_북쪽.png
# [82] 금상초등학교 수집 중...
#   ✅ [금상초등학교] 저장 완료 → ./roadview_images/금상초등학교_북쪽.png
# [83] 상원초등학교 수집 중...
#   ✅ [상원초등학교] 저장 완료 → ./roadview_images/상원초등학교_북쪽.png
# [84] 상탑초등학교 수집 중...
#   ✅ [상탑초등학교] 저장 완료 → ./roadview_images/상탑초등학교_북쪽.png
# [85] 서현초등학교 수집 중...
#   ✅ [서현초등학교] 저장 완료 → ./roadview_images/서현초등학교_북쪽.png
# [86] 성남장안초등학교 수집 중...
#   ✅ [성남장안초등학교] 저장 완료 → ./roadview_images/성남장안초등학교_북쪽.png
# [87] 안말초등학교 수집 중...
#   ✅ [안말초등학교] 저장 완료 → ./roadview_images/안말초등학교_북쪽.png
# [88] 야탑초등학교 수집 중...
#   ✅ [야탑초등학교] 저장 완료 → ./roadview_images/야탑초등학교_북쪽.png
# [89] 오리초등학교 수집 중...
#   ✅ [오리초등학교] 저장 완료 → ./roadview_images/오리초등학교_북쪽.png
# [90] 이매초등학교 수집 중...
#   ✅ [이매초등학교] 저장 완료 → ./roadview_images/이매초등학교_북쪽.png
# [91] 청솔초등학교 수집 중...
#   ✅ [청솔초등학교] 저장 완료 → ./roadview_images/청솔초등학교_북쪽.png
# [92] 중원초등학교 수집 중...
#   ✅ [중원초등학교] 저장 완료 → ./roadview_images/중원초등학교_북쪽.png
# [93] 중부초등학교 수집 중...
#   ✅ [중부초등학교] 저장 완료 → ./roadview_images/중부초등학교_북쪽.png
# [94] 도촌초등학교 수집 중...
#   ✅ [도촌초등학교] 저장 완료 → ./roadview_images/도촌초등학교_북쪽.png
# [95] 구미초등학교 수집 중...
#   ✅ [구미초등학교] 저장 완료 → ./roadview_images/구미초등학교_북쪽.png
# [96] 돌마초등학교 수집 중...
#   ✅ [돌마초등학교] 저장 완료 → ./roadview_images/돌마초등학교_북쪽.png
# [97] 미금초등학교 수집 중...
#   ✅ [미금초등학교] 저장 완료 → ./roadview_images/미금초등학교_북쪽.png
# [98] 분당초등학교 수집 중...
#   ✅ [분당초등학교] 저장 완료 → ./roadview_images/분당초등학교_북쪽.png
# [99] 성남여수초등학교 수집 중...
#   ✅ [성남여수초등학교] 저장 완료 → ./roadview_images/성남여수초등학교_북쪽.png
# [100] 보평초등학교 수집 중...
#   ✅ [보평초등학교] 저장 완료 → ./roadview_images/보평초등학교_북쪽.png
# [101] 낙생초등학교 수집 중...
#   ✅ [낙생초등학교] 저장 완료 → ./roadview_images/낙생초등학교_북쪽.png
# [102] 성남은행초등학교 수집 중...
#   ✅ [성남은행초등학교] 저장 완료 → ./roadview_images/성남은행초등학교_북쪽.png
# [103] 창조유치원 수집 중...
#   ✅ [창조유치원] 저장 완료 → ./roadview_images/창조유치원_북쪽.png
# [104] 꾸러기유치원 수집 중...
#   ✅ [꾸러기유치원] 저장 완료 → ./roadview_images/꾸러기유치원_북쪽.png
# [105] 은혜유치원 수집 중...
#   ✅ [은혜유치원] 저장 완료 → ./roadview_images/은혜유치원_북쪽.png
# [106] 희영유치원 수집 중...
#   ✅ [희영유치원] 저장 완료 → ./roadview_images/희영유치원_북쪽.png
# [107] 단대어린이집 수집 중...
#   ✅ [단대어린이집] 저장 완료 → ./roadview_images/단대어린이집_북쪽.png
# [108] 신흥제2어린이집 수집 중...
#   ✅ [신흥제2어린이집] 저장 완료 → ./roadview_images/신흥제2어린이집_북쪽.png
# [109] 한솔초등학교 수집 중...
#   ✅ [한솔초등학교] 저장 완료 → ./roadview_images/한솔초등학교_북쪽.png
# [110] 성남송현초등학교 수집 중...
#   ✅ [성남송현초등학교] 저장 완료 → ./roadview_images/성남송현초등학교_북쪽.png
# [111] 위례하늘유치원 수집 중...
#   ✅ [위례하늘유치원] 저장 완료 → ./roadview_images/위례하늘유치원_북쪽.png
# [112] 단남초등학교 수집 중...
#   ✅ [단남초등학교] 저장 완료 → ./roadview_images/단남초등학교_북쪽.png
# [113] 대하초등학교 수집 중...
#   ✅ [대하초등학교] 저장 완료 → ./roadview_images/대하초등학교_북쪽.png
# [114] 복정초등학교 수집 중...
#   ✅ [복정초등학교] 저장 완료 → ./roadview_images/복정초등학교_북쪽.png
# [115] 위례고운초등학교 수집 중...
#   ✅ [위례고운초등학교] 저장 완료 → ./roadview_images/위례고운초등학교_북쪽.png
# [116] 위례중앙초등학교 수집 중...
#   ✅ [위례중앙초등학교] 저장 완료 → ./roadview_images/위례중앙초등학교_북쪽.png
# [117] 불정초등학교 수집 중...
#   ✅ [불정초등학교] 저장 완료 → ./roadview_images/불정초등학교_북쪽.png
# [118] 성남신기초등학교 수집 중...
#   ✅ [성남신기초등학교] 저장 완료 → ./roadview_images/성남신기초등학교_북쪽.png
# [119] 하원초등학교 수집 중...
#   ✅ [하원초등학교] 저장 완료 → ./roadview_images/하원초등학교_북쪽.png
# [120] 상대원초등학교 수집 중...
#   ✅ [상대원초등학교] 저장 완료 → ./roadview_images/상대원초등학교_북쪽.png
# [121] 내정초등학교 수집 중...
#   ✅ [내정초등학교] 저장 완료 → ./roadview_images/내정초등학교_북쪽.png
# [122] 백현초등학교 수집 중...
#   ✅ [백현초등학교] 저장 완료 → ./roadview_images/백현초등학교_북쪽.png
# [123] 탄천초등학교 수집 중...
#   ✅ [탄천초등학교] 저장 완료 → ./roadview_images/탄천초등학교_북쪽.png
# [124] 위례새초롱유치원 수집 중...
#   ✅ [위례새초롱유치원] 저장 완료 → ./roadview_images/위례새초롱유치원_북쪽.png
# [125] 선경유치원 수집 중...
#   ✅ [선경유치원] 저장 완료 → ./roadview_images/선경유치원_북쪽.png
# [126] 도촌유치원 수집 중...
#   ✅ [도촌유치원] 저장 완료 → ./roadview_images/도촌유치원_북쪽.png
# [127] 안촌 유치원 수집 중...
#   ✅ [안촌 유치원] 저장 완료 → ./roadview_images/안촌_유치원_북쪽.png
# [128] 꿈터 유치원 수집 중...
#   ✅ [꿈터 유치원] 저장 완료 → ./roadview_images/꿈터_유치원_북쪽.png
# [129] 서울국제학교 수집 중...
#   ✅ [서울국제학교] 저장 완료 → ./roadview_images/서울국제학교_북쪽.png
# [130] 성남초등학교 수집 중...
#   ✅ [성남초등학교] 저장 완료 → ./roadview_images/성남초등학교_북쪽.png
# [131] 서당초등학교 수집 중...
#   ✅ [서당초등학교] 저장 완료 → ./roadview_images/서당초등학교_북쪽.png
# [132] 양영초등학교 수집 중...
#   ✅ [양영초등학교] 저장 완료 → ./roadview_images/양영초등학교_북쪽.png
# [133] 판교대장초등학교 수집 중...
#   ✅ [판교대장초등학교] 저장 완료 → ./roadview_images/판교대장초등학교_북쪽.png
# [134] 신흥성모유치원 수집 중...
#   ✅ [신흥성모유치원] 저장 완료 → ./roadview_images/신흥성모유치원_북쪽.png
# [135] 복정어린이집 수집 중...
#   ✅ [복정어린이집] 저장 완료 → ./roadview_images/복정어린이집_북쪽.png
# [136] 다솜어린이집 수집 중...
#   ✅ [다솜어린이집] 저장 완료 → ./roadview_images/다솜어린이집_북쪽.png
# [137] 하대원어린이집 수집 중...
#   ✅ [하대원어린이집] 저장 완료 → ./roadview_images/하대원어린이집_북쪽.png
# [138] 판교어린이집 수집 중...
#   ✅ [판교어린이집] 저장 완료 → ./roadview_images/판교어린이집_북쪽.png
# [139] 성남생명숲어린이집 수집 중...
#   ✅ [성남생명숲어린이집] 저장 완료 → ./roadview_images/성남생명숲어린이집_북쪽.png
# [140] 늘사랑어린이집 수집 중...
#   ✅ [늘사랑어린이집] 저장 완료 → ./roadview_images/늘사랑어린이집_북쪽.png
# [141] 수내동어린이집 수집 중...
#   ✅ [수내동어린이집] 저장 완료 → ./roadview_images/수내동어린이집_북쪽.png
